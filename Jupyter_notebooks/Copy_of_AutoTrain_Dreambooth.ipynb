# %%
#@title 🤗 AutoTrain DreamBooth
#@markdown In order to use this colab
#@markdown - upload images to a folder named `images/`
#@markdown - choose a project name if you wish
#@markdown - change model if you wish, you can also select sd2/2.1 or sd1.5
#@markdown - update prompt and remember it. choose keywords that don't usually appear in dictionaries
#@markdown - add huggingface information (token and repo_id) if you wish to push trained model to huggingface hub
#@markdown - update hyperparameters if you wish
#@markdown - click `Runtime > Run all` or run each cell individually
#@markdown - report issues / feature requests here: https://github.com/huggingface/autotrain-advanced/issues

import os
# !pip install -U autotrain-advanced > install_logs.txt
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@markdown ---
#@markdown #### Project Config
project_name = 'Auto_Train_ND_SDXL' # @param {type:"string"}
model_name = 'stabilityai/stable-diffusion-xl-base-1.0' # @param ["stabilityai/stable-diffusion-xl-base-1.0", "runwayml/stable-diffusion-v1-5", "stabilityai/stable-diffusion-2-1", "stabilityai/stable-diffusion-2-1-base"]
prompt = 'photo of a sks woman' # @param {type: "string"}

#@markdown ---
#@markdown #### Push to Hub?
#@markdown Use these only if you want to push your trained model to a private repo in your Hugging Face Account
#@markdown If you dont use these, the model will be saved in Google Colab and you are required to download it manually.
#@markdown Please enter your Hugging Face write token. The trained model will be saved to your Hugging Face account.
#@markdown You can find your token here: https://huggingface.co/settings/tokens
push_to_hub = True # @param ["False", "True"] {type:"raw"}
hf_token = "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" #@param {type:"string"}
repo_id = "Bilal326/ND_SDXL" #@param {type:"string"}

#@markdown ---
#@markdown #### Hyperparameters
learning_rate = 1e-5 # @param {type:"number"}
num_steps = 7500 #@param {type:"number"}
batch_size = 1 # @param {type:"slider", min:1, max:32, step:1}
gradient_accumulation = 4 # @param {type:"slider", min:1, max:32, step:1}
resolution = 512 # @param {type:"slider", min:128, max:1024, step:128}
use_8bit_adam = False # @param ["False", "True"] {type:"raw"}
use_xformers = True # @param ["False", "True"] {type:"raw"}
use_fp16 = True # @param ["False", "True"] {type:"raw"}
train_text_encoder = False # @param ["False", "True"] {type:"raw"}
disable_gradient_checkpointing = False # @param ["False", "True"] {type:"raw"}

os.environ["PROJECT_NAME"] = project_name
os.environ["MODEL_NAME"] = model_name
os.environ["PROMPT"] = prompt
os.environ["PUSH_TO_HUB"] = str(push_to_hub)
os.environ["HF_TOKEN"] = hf_token
os.environ["REPO_ID"] = repo_id
os.environ["LEARNING_RATE"] = str(learning_rate)
os.environ["NUM_STEPS"] = str(num_steps)
os.environ["BATCH_SIZE"] = str(batch_size)
os.environ["GRADIENT_ACCUMULATION"] = str(gradient_accumulation)
os.environ["RESOLUTION"] = str(resolution)
os.environ["USE_8BIT_ADAM"] = str(use_8bit_adam)
os.environ["USE_XFORMERS"] = str(use_xformers)
os.environ["USE_FP16"] = str(use_fp16)
os.environ["TRAIN_TEXT_ENCODER"] = str(train_text_encoder)
os.environ["DISABLE_GRADIENT_CHECKPOINTING"] = str(disable_gradient_checkpointing)

# %%
# %pip install -q accelerate transformers ftfy bitsandbytes==0.35.0 gradio natsort safetensors xformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 65.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 91.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 83.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autotrain-advanced 0.6.79 requires bitsandbytes==0.41.0, but you have bitsandbytes 0.35.0 which is incompatible.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.

# %%
# !autotrain dreambooth \
--model ${MODEL_NAME} \
--project-name ${PROJECT_NAME} \
--image-path /content/drive/MyDrive/DL_Project/ND_squared \
--prompt "${PROMPT}" \
--resolution ${RESOLUTION} \
--batch-size ${BATCH_SIZE} \
--num-steps ${NUM_STEPS} \
--gradient-accumulation ${GRADIENT_ACCUMULATION} \
--lr ${LEARNING_RATE} \
$( [[ "$USE_FP16" == "True" ]] && echo "--fp16" ) \
$( [[ "$USE_XFORMERS" == "True" ]] && echo "--xformers" ) \
$( [[ "$TRAIN_TEXT_ENCODER" == "True" ]] && echo "--train-text-encoder" ) \
$( [[ "$USE_8BIT_ADAM" == "False" ]] && echo "--use-8bit-adam" ) \
$( [[ "$DISABLE_GRADIENT_CHECKPOINTING" == "True" ]] && echo "--disable_gradient-checkpointing" ) \
$( [[ "$PUSH_TO_HUB" == "True" ]] && echo "--push-to-hub --token ${HF_TOKEN} --repo-id ${REPO_ID}" )
# Out:
# > INFO    Namespace(version=False, revision=None, tokenizer=None, image_path='/content/drive/MyDrive/DL_Project/ND_squared', class_image_path=None, prompt='photo of a sks woman', class_prompt=None, num_class_images=100, class_labels_conditioning=None, prior_preservation=None, prior_loss_weight=1.0, resolution=512, center_crop=None, train_text_encoder=None, sample_batch_size=4, num_steps=7500, checkpointing_steps=100000, resume_from_checkpoint=None, scale_lr=None, scheduler='constant', warmup_steps=0, num_cycles=1, lr_power=1.0, dataloader_num_workers=0, use_8bit_adam=True, adam_beta1=0.9, adam_beta2=0.999, adam_weight_decay=0.01, adam_epsilon=1e-08, max_grad_norm=1.0, allow_tf32=None, prior_generation_precision=None, local_rank=-1, xformers=True, pre_compute_text_embeddings=None, tokenizer_max_length=None, text_encoder_use_attention_mask=None, rank=4, xl=None, fp16=True, bf16=None, validation_prompt=None, num_validation_images=4, validation_epochs=50, checkpoints_total_limit=None, validation_images=None, logging=None, train=None, deploy=None, inference=None, username=None, backend='local-cli', token='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', repo_id='Bilal326/ND_SDXL', push_to_hub=True, model='stabilityai/stable-diffusion-xl-base-1.0', project_name='Auto_Train_ND_SDXL', seed=42, epochs=1, gradient_accumulation=4, disable_gradient_checkpointing=None, lr=1e-05, log='none', data_path=None, train_split='train', valid_split=None, batch_size=1, func=<function run_dreambooth_command_factory at 0x798004bbbf40>)
# > INFO    Running DreamBooth Training
# > WARNING Parameters supplied but not used: train_split, valid_split, func, version, deploy, data_path, train, backend, inference, log
# > INFO    Dataset: Auto_Train_ND_SDXL (dreambooth)
#
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (2).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (3).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (1).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (7).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (15).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (14).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (17).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (12).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (16).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (10).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (9).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (4).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (11).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (5).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (13).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (6).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (8).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (26).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (24).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (30).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (33).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (19).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (28).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (27).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (29).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (20).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (22).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (32).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (21).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (31).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (18).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (25).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (23).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (36).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (42).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (39).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (44).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (46).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (40).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (45).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (48).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (41).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (34).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (35).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (38).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (47).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (37).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (43).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (54).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (62).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (53).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (60).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (65).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (56).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (52).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (64).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (63).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (51).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (55).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (59).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (49).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (58).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (57).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (50).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (61).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (75).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (66).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (78).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (76).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (67).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (69).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (74).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (79).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (73).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (68).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (70).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (77).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (72).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (80).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (71).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (93).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (87).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (90).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (85).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (91).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (89).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (88).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (82).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (81).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (94).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (83).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (92).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (86).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (84).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (96).jpg
# > INFO    Saving concept images
# > INFO    /content/drive/MyDrive/DL_Project/ND_squared/natd (95).jpg
# > INFO    Starting local training...
# > INFO    {"model":"stabilityai/stable-diffusion-xl-base-1.0","revision":null,"tokenizer":null,"image_path":"Auto_Train_ND_SDXL/autotrain-data","class_image_path":null,"prompt":"photo of a sks woman","class_prompt":null,"num_class_images":100,"class_labels_conditioning":null,"prior_preservation":false,"prior_loss_weight":1.0,"project_name":"Auto_Train_ND_SDXL","seed":42,"resolution":512,"center_crop":false,"train_text_encoder":false,"batch_size":1,"sample_batch_size":4,"epochs":1,"num_steps":7500,"checkpointing_steps":100000,"resume_from_checkpoint":null,"gradient_accumulation":4,"disable_gradient_checkpointing":false,"lr":0.00001,"scale_lr":false,"scheduler":"constant","warmup_steps":0,"num_cycles":1,"lr_power":1.0,"dataloader_num_workers":0,"use_8bit_adam":true,"adam_beta1":0.9,"adam_beta2":0.999,"adam_weight_decay":0.01,"adam_epsilon":1e-8,"max_grad_norm":1.0,"allow_tf32":false,"prior_generation_precision":null,"local_rank":-1,"xformers":true,"pre_compute_text_embeddings":false,"tokenizer_max_length":null,"text_encoder_use_attention_mask":false,"rank":4,"xl":true,"fp16":true,"bf16":false,"token":"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","repo_id":"Bilal326/ND_SDXL","push_to_hub":true,"username":null,"validation_prompt":null,"num_validation_images":4,"validation_epochs":50,"checkpoints_total_limit":null,"validation_images":null,"logging":false}
# > INFO    ['python', '-m', 'autotrain.trainers.dreambooth', '--training_config', 'Auto_Train_ND_SDXL/training_params.json']
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'dropout', 'attention_type'} was not found in config. Values will be initialized to default values.
# {'dynamic_thresholding_ratio', 'thresholding', 'variance_type', 'clip_sample_range'} was not found in config. Values will be initialized to default values.
# 🚀 INFO   | 2023-12-25 17:31:01 | autotrain.trainers.dreambooth.utils:enable_xformers:308 - Enabling xformers
# 🚀 INFO   | 2023-12-25 17:31:01 | autotrain.trainers.dreambooth.utils:enable_gradient_checkpointing:298 - Enabling gradient checkpointing.
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/usr/local/lib/python3.10/dist-packages/cv2/../../lib64')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:105: UserWarning: /usr/local/lib/python3.10/dist-packages/cv2/../../lib64:/usr/local/lib/python3.10/dist-packages/cv2/../../lib64:/usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('stabilityai/stable-diffusion-xl-base-1.0')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('Bilal326/ND_SDXL')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.28.0.1'), PosixPath('http'), PosixPath('8013')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https'), PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-v100-hm-hb1jcriyifnw --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/datalab/web/pyright/typeshed-fallback/stdlib,/usr/local/lib/python3.10/dist-packages')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//ipykernel.pylab.backend_inline')}
#   warn(
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.0
# CUDA SETUP: Detected CUDA version 122
# CUDA SETUP: TODO: compile library for specific version: libbitsandbytes_cuda122_nocublaslt.so
# CUDA SETUP: Defaulting to libbitsandbytes.so...
# CUDA SETUP: CUDA detection failed. Either CUDA driver not installed, CUDA not installed, or you have multiple conflicting CUDA libraries!
# CUDA SETUP: If you compiled from source, try again with `make CUDA_VERSION=DETECTED_CUDA_VERSION` for example, `make CUDA_VERSION=113`.
# ❌ ERROR  | 2023-12-25 17:31:01 | autotrain.trainers.common:wrapper:90 - train has failed due to an exception: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/trainers/common.py", line 87, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/trainers/dreambooth/__main__.py", line 278, in train
#     optimizer = utils.get_optimizer(config, unet_lora_parameters, text_lora_parameters)
#   File "/usr/local/lib/python3.10/dist-packages/autotrain/trainers/dreambooth/utils.py", line 325, in get_optimizer
#     import bitsandbytes as bnb
#   File "/usr/local/lib/python3.10/dist-packages/bitsandbytes/__init__.py", line 6, in <module>
#     from .autograd._functions import (
#   File "/usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py", line 5, in <module>
#     import bitsandbytes.functional as F
#   File "/usr/local/lib/python3.10/dist-packages/bitsandbytes/functional.py", line 13, in <module>
#     from .cextension import COMPILED_WITH_CUDA, lib
#   File "/usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py", line 41, in <module>
#     lib = CUDALibrary_Singleton.get_instance().lib
#   File "/usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py", line 37, in get_instance
#     cls._instance.initialize()
#   File "/usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py", line 27, in initialize
#     raise Exception('CUDA SETUP: Setup Failed!')
# Exception: CUDA SETUP: Setup Failed!
#
# ❌ ERROR  | 2023-12-25 17:31:01 | autotrain.trainers.common:wrapper:91 - CUDA SETUP: Setup Failed!

# %%
# Inference
# this is the inference code that you can use after you have trained your model
# Unhide code below and change prj_path to your repo or local path (e.g. my_dreambooth_project)
#
#
#
# from diffusers import DiffusionPipeline, StableDiffusionXLImg2ImgPipeline
# import torch

# prj_path = "username/repo_name"
# model = "stabilityai/stable-diffusion-xl-base-1.0"
# pipe = DiffusionPipeline.from_pretrained(
#     model,
#     torch_dtype=torch.float16,
# )
# pipe.to("cuda")
# pipe.load_lora_weights(prj_path, weight_name="pytorch_lora_weights.safetensors")

# refiner = StableDiffusionXLImg2ImgPipeline.from_pretrained(
#     "stabilityai/stable-diffusion-xl-refiner-1.0",
#     torch_dtype=torch.float16,
# )
# refiner.to("cuda")

# prompt = "photo of a sks dog in a bucket"

# seed = 42
# generator = torch.Generator("cuda").manual_seed(seed)
# image = pipe(prompt=prompt, generator=generator).images[0]
# image = refiner(prompt=prompt, generator=generator, image=image).images[0]
# image.save(f"generated_image.png")
