# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
# !pwd
# Out:
# /content

# %%
# from huggingface_hub import Repository
# repo = Repository(local_dir="SD_2.0_DreamBooth_DragonWarrior", clone_from="Bilal326/SD_2.0_DreamBooth_DragonWarrior")

# %%
# !pip install diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/huggingface/diffusers
# !pip install -qq accelerate transformers ftfy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 2.4 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer
from diffusers import StableDiffusionPipeline

# Load the tokenizer and pipeline
# tokenizer = AutoTokenizer.from_pretrained("Bilal326/SD_2.0_DreamBooth_DragonWarrior")
pipe = StableDiffusionPipeline.from_pretrained("Bilal326/SD_2.0_DreamBooth_DragonWarrior", use_auth_token="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")
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
prompt = "A majestic panda standing on top of a mountain"  # Example prompt
image = pipe(prompt).images[0]  # Generate an image from the prompt
# image.save("generated_image.png")  # Save the image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
