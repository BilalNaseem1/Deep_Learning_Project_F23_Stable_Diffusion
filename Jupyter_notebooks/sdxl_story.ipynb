# %%
# !pip install autotrain-advanced
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.4/520.4 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 27.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 351.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 35.0 MB/s eta 0:00:00
# ...

# %%
script_content = """
from diffusers import DiffusionPipeline
import torch

pipeline = DiffusionPipeline.from_pretrained(
    "stablediffusionapi/juggernaut-xl-v7", torch_dtype=torch.float16
).to("cuda")
pipeline.load_lora_weights("Bilal326/ND_AutoTrain_LoRA", weight_name="pytorch_lora_weights.safetensors")
pipeline.fuse_lora(lora_scale=0.7)
"""

with open("download_model.py", "w") as file:
    file.write(script_content)

# !python download_model.py
# Out:
# text_encoder_2/model.safetensors not found
# Fetching 18 files:   0% 0/18 [00:00<?, ?it/s]
# scheduler/scheduler_config.json: 100% 474/474 [00:00<00:00, 2.78MB/s]
# Fetching 18 files:  11% 2/18 [00:01<00:08,  1.93it/s]
# tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
# text_encoder_2/config.json: 100% 570/570 [00:00<00:00, 2.44MB/s]
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 10.1MB/s]
#
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 10.2MB/s]
#
# tokenizer/tokenizer_config.json: 100% 704/704 [00:00<00:00, 4.25MB/s]
#
# text_encoder/config.json: 100% 560/560 [00:00<00:00, 3.10MB/s]
# Fetching 18 files:  17% 3/18 [00:01<00:05,  2.80it/s]
# tokenizer_2/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
# tokenizer_2/tokenizer_config.json: 100% 855/855 [00:00<00:00, 4.76MB/s]
#
#
# unet/config.json: 100% 1.77k/1.77k [00:00<00:00, 9.76MB/s]
# tokenizer_2/merges.txt: 100% 525k/525k [00:00<00:00, 7.66MB/s]
#
# ...

# %%
from diffusers import DiffusionPipeline
import torch

pipeline = DiffusionPipeline.from_pretrained(
    "stablediffusionapi/juggernaut-xl-v7", torch_dtype=torch.float16
).to("cuda")
pipeline.load_lora_weights("Bilal326/ND_AutoTrain_LoRA", weight_name="pytorch_lora_weights.safetensors")
pipeline.fuse_lora(lora_scale=0.7)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# text_encoder_2/model.safetensors not found
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# The config attributes {'reverse_transformer_layers_per_block': None} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# ...

# %%
from diffusers import DiffusionPipeline, StableDiffusionXLImg2ImgPipeline

# %%
torch.cuda.manual_seed(42)

prompt = "sks woman with dark brown hair in ancient greece, game of thrones theme, side pose looking down at the poeple who are below"

for seed in range(5):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/s1r5/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
torch.cuda.manual_seed(42)

prompt = "sks woman with half shaved head in a tight black dress, futuristic, mockingjay theme"

for seed in range(5):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/s1r5/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
torch.cuda.manual_seed(42)

prompt = "(sparkling elegant haired:2.5) sks woman, abstract beauty, approaching perfection, \
looking at camera, dynamic, moon, highly detailed, busty, digital painting, artstation, \
concept art, smooth, sharp focus, illustration, art by Carne Griffiths and Wadim Kashin,\
 black orange and dark red colours, (smoke, steam and thick smoke:2.5), (covered in smoke:2.5),"
negative_prompt = "topless, nude, naked, (worst quality, low quality, normal quality, lowres, low details, \
oversaturated, undersaturated, overexposed, underexposed, grayscale, bw, bad photo, bad photography, bad art:1.4), \
(watermark, signature, text font, username, error, logo, words, letters, digits, autograph, trademark, name:1.2), \
(blur, blurry, grainy), morbid, ugly, asymmetrical, mutated malformed, mutilated, poorly lit, bad shadow, draft, cropped,\
 out of frame, cut off, censored, jpeg artifacts, out of focus, glitch, duplicate, (airbrushed, cartoon, anime, semi-realistic,\
  cgi, render, blender, digital art, manga, amateur:1.3), (3D ,3D Game, 3D Game Scene, 3D Character:1.1),\
   (bad hands, bad anatomy, bad body, bad face, bad teeth, bad arms, bad legs, deformities:1.3)"

for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline(prompt=prompt, generator=generator, negative_prompt =  negative_prompt, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/s1r6/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['5 ), ( covered in smoke : 2. 5 ),']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['5 ), ( covered in smoke : 2. 5 ),']
#   0%|          | 0/25 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['5 ), ( covered in smoke : 2. 5 ),']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['5 ), ( covered in smoke : 2. 5 ),']
#   0%|          | 0/25 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['5 ), ( covered in smoke : 2. 5 ),']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['5 ), ( covered in smoke : 2. 5 ),']
#   0%|          | 0/25 [00:00<?, ?it/s]
# ...

# %%
from diffusers import DiffusionPipeline
import torch

pipeline2 = DiffusionPipeline.from_pretrained(
    "stablediffusionapi/juggernaut-xl-v7", torch_dtype=torch.float16
).to("cuda")
pipeline2.load_lora_weights("Bilal326/ND_AutoTrain_LoRA", weight_name="pytorch_lora_weights.safetensors")
pipeline2.fuse_lora(lora_scale=0.9)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# text_encoder/model.safetensors not found
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# The config attributes {'reverse_transformer_layers_per_block': None} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
torch.cuda.manual_seed(42)

prompt = "sks has white pixie haircut, dark grey trasparent open button shirt, golden makeup , simple jewelry, realistic skin pores , two light moles,\
BREAK sexy, attractive , erotic, half body shot , flowing pose, sensual ,\
BREAK low-key lighting photograph, in the style of photo shooting, chiaroscuro lighting,  textured background with vintage decoration , medium format photography, Kodak portra colors"
negative_prompt = "Bra, Semi-closed lips, Low quality , blur, 3d, render, ci, cg, cartoon, unreal, amateur, poorly drawn, ugly, flat, latex, sunny day, nsfw , oiled skin, candles"

for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, negative_prompt =  negative_prompt, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/s1r7/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (83 > 77). Running this sequence through the model will result in indexing errors
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['photography, kodak portra colors']
# Token indices sequence length is longer than the specified maximum sequence length for this model (83 > 77). Running this sequence through the model will result in indexing errors
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['photography, kodak portra colors']
#   0%|          | 0/25 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['photography, kodak portra colors']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['photography, kodak portra colors']
# ...

# %%
# !zip -r /content/scene_1r2.zip /content/scene_1r2
# Out:
#   adding: content/scene_1r2/ (stored 0%)
#   adding: content/scene_1r2/5.png (deflated 0%)
#   adding: content/scene_1r2/2.png (deflated 0%)
#   adding: content/scene_1r2/1.png (deflated 0%)
#   adding: content/scene_1r2/9.png (deflated 0%)
#   adding: content/scene_1r2/8.png (deflated 0%)
#   adding: content/scene_1r2/0.png (deflated 0%)
#   adding: content/scene_1r2/7.png (deflated 0%)
#   adding: content/scene_1r2/4.png (deflated 0%)
#   adding: content/scene_1r2/3.png (deflated 0%)
#   adding: content/scene_1r2/6.png (deflated 0%)

# %%
torch.cuda.manual_seed(42)

prompt = "(sks: 0.7), photograph, blur background, neon, sharp, high quality, saturation, contrast,\
 masterpiece, 8k uhd, front camera view, cheeks, girl, pink hair, medium hair, messy hair, floating hair, blue eyes, \
 thick body, normal body weight, huge breasts, upper body, home, livingroom, green, yellow, beaultiful sunset, at work, \
 covered neck, plaid red sweater, scarf, on knees, head tilt, cute smile, gazing down"
negative_prompt = "(cleavage: 1.4), bad quality, bad anatomy, worst quality, low quality, low resolution, extra fingers, \
blur, blurry, ugly, wrong proportions, watermark, image artifacts, lowres, ugly, jpeg artifacts, deformed, noisy image, \
deformation, FastNegativeV2"

for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, negative_prompt =  negative_prompt, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/s1r8/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', beaultiful sunset, at work, covered neck, plaid red sweater, scarf, on knees, head tilt, cute smile, gazing down']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', beaultiful sunset, at work, covered neck, plaid red sweater, scarf, on knees, head tilt, cute smile, gazing down']
#   0%|          | 0/25 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', beaultiful sunset, at work, covered neck, plaid red sweater, scarf, on knees, head tilt, cute smile, gazing down']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', beaultiful sunset, at work, covered neck, plaid red sweater, scarf, on knees, head tilt, cute smile, gazing down']
#   0%|          | 0/25 [00:00<?, ?it/s]
# ...

# %%
prompt = "sks woman with dark brown hair in ancient greece, game of thrones theme"

for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/s1r9/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "sks woman with dark brown hair in an Ancient Greek marketplace, Game of Thrones theme. She's in a crowd, surrounded by stone buildings and vibrant market stalls."


for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/1/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "sks woman with dark brown hair at an Ancient Greek temple, Game of Thrones theme. She's standing near marble columns, with an expansive view of the sea in the background."


for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/2/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "A philosopher in an Ancient Greek garden, Game of Thrones theme. Seated among marble statues and lush greenery, the philosopher is deep in thought, writing in a parchment scroll."


for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/3/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "A noble Ancient Greek family at a lavish feast, Game of Thrones theme. The banquet hall is grand, with elaborate frescoes and a long table adorned with exotic foods."


for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/4/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "A group of Ancient Greek soldiers strategizing in a war room, Game of Thrones theme. The room is filled with maps and ancient weaponry, a sense of tension in the air."


for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/5/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "An Ancient Greek oracle in a mystical temple, Game of Thrones theme. Surrounded by flickering candles and mysterious symbols, the oracle gazes into a fire, foretelling events."


for seed in range(10):
    generator = torch.Generator("cuda").manual_seed(seed)
    image = pipeline2(prompt=prompt, generator=generator, num_inference_steps=25)
    image = image.images[0]
    image.save(f"/content/6/{seed}.png")
    # image = refiner(prompt=prompt, generator=generator, image=image)
    # image = image.images[0]
    # image.save(f"/content/sks_woman_refined/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
# !zip -r /content/6.zip /content/6
# Out:
#   adding: content/6/ (stored 0%)
#   adding: content/6/5.png (deflated 0%)
#   adding: content/6/2.png (deflated 0%)
#   adding: content/6/1.png (deflated 0%)
#   adding: content/6/9.png (deflated 0%)
#   adding: content/6/8.png (deflated 0%)
#   adding: content/6/0.png (deflated 0%)
#   adding: content/6/7.png (deflated 0%)
#   adding: content/6/4.png (deflated 0%)
#   adding: content/6/3.png (deflated 0%)
#   adding: content/6/6.png (deflated 0%)
